# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from datetime import datetime
# %matplotlib inline

# %%
df=pd.read_excel('D:/Second_paper_data/COVID-EMDA-master/data_release/all_cities/All_cities_prediction.xlsx', parse_dates=['date'])

# %%
df.head()
# Out:
#         date  total_load_la  prediction_la  total_load_houston  \
# 0 2020-12-01          69594   69058.200476            281048.3
# 1 2020-12-02          69824   68771.650651            258271.4
# 2 2020-12-03          69469   69910.778655            271120.2
# 3 2020-12-04          73951   68612.306398            273958.5
# 4 2020-12-05          66501   65460.628625            265903.7
#
#    prediction_houston  total_load_boston  prediction_boston  total_load_nyc  \
# 0       268897.064026            59197.5       61786.879942        120105.7
# 1       268684.743298            61618.4       61161.185797        125820.8
# 2       269380.098196            61666.6       61627.288364        125114.3
# 3       266107.636057            60010.9       61486.892243        123636.2
# 4       253992.216819            60796.9       59441.806615        116929.5
#
#    prediction_nyc  total_load_chicago  prediction_chicago  total_load_phila  \
# ...

# %%
colors = sns.color_palette()
c1, c2, c3, c4, c5, c6,c7= colors[0], colors[1], colors[2], colors[3], colors[4], colors[5],colors[6]
fig = plt.figure()
fig.set_size_inches(12,10)

#fig = plt.figure(figsize=(14, 12))
ax = fig.add_subplot(4, 2, 1)
ax.plot(df['date'], df['total_load_la'], lw=3, label="Actual", c=c1,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['prediction_la'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("Los Angeles")
ax.set_ylim(40000,80000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 2)
ax.plot(df['date'], df['total_load_houston'], lw=3, label="Actual", c=c1,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['prediction_houston'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("Houston")
ax.set_ylim(220000,340000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 3)
ax.plot(df['date'], df['total_load_boston'], lw=3, label="Actual", c=c1,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['prediction_boston'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("Boston")
ax.set_ylim(50000,90000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 4)
ax.plot(df['date'], df['total_load_nyc'], lw=3, label="Actual", c=c1,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['prediction_nyc'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("New York City")
ax.set_ylim(100000,150000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 5)
ax.plot(df['date'], df['total_load_chicago'], lw=3, label="Actual", c=c1,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['prediction_chicago'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("Chicago")
ax.set_ylim(210000,300000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 6)
ax.plot(df['date'], df['total_load_phila'], lw=3, label="Actual", c=c1,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['prediction_phila'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_xlabel("Date")
ax.set_title("Philadelphia")
ax.set_ylim(80000,140000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 7)
ax.plot(df['date'], df['total_load_kck'], lw=3, label="Kansas City", c=c1,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['prediction_kck'], lw=3, label="Los Angeles", c=c2,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_xlabel("Date")
ax.set_title("Kansas City")
ax.set_ylim(30000,55000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
#fig.suptitle("Electricity Demand in New York (2009-2020)",fontsize=15)
#fig.autofmt_xdate()

plt.tight_layout()
fig.subplots_adjust(top=0.95)
plt.show()
