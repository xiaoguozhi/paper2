# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from datetime import datetime
# %matplotlib inline

# %%
df1=pd.read_excel('D:/Second_paper_data/COVID-EMDA-master/data_release/all_cities/All_cities_42days_causal_impact.xlsx', parse_dates=['date'])

# %%
df1.head()
# Out:
#         date  la_load  la_prediction  houston_load  houston_prediction  \
# 0 2019-01-01  66469.0   66506.338100      236041.7       236985.894270
# 1 2019-01-02  74406.0   74369.659287      259888.8       259116.921165
# 2 2019-01-03  74665.0   74651.715270      267176.1       266863.347564
# 3 2019-01-04  75629.0   75561.314883      269066.7       267452.032600
# 4 2019-01-05  71496.0   71424.141769      239342.6       239786.176540
#
#    boston_load  boston_prediction  nyc_load  nyc_prediction  chicago_load  \
# 0      58938.0       60486.000886  119612.8     119802.5457      234574.1
# 1      67663.3       66181.299644  136366.9     136238.0726      273493.5
# 2      66767.6       66478.027065  136377.7     136356.2317      273140.4
# 3      64624.7       65239.707764  136047.5     136187.1057      260676.8
# 4      61566.2       62164.321101  124706.6     124681.8229      235011.3
#
#    chicago_prediction  phila_load  phila_prediction  kck_load  kck_prediction
# ...

# %%
df = df1[(df1['date'] >= '2020-03-13') & (df1['date'] <= '2020-04-24')]

# %%
colors = sns.color_palette()
c1, c2, c3, c4, c5, c6,c7= colors[0], colors[1], colors[2], colors[3], colors[4], colors[5],colors[6]
fig = plt.figure()
fig.set_size_inches(10,10)

#fig = plt.figure(figsize=(14, 12))
ax = fig.add_subplot(4, 2, 1)
ax.plot(df['date'], df['la_load'], lw=3, label="Actual", c=c5,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['la_prediction'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dotted',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("Los Angeles")
ax.set_ylim(50000,85000)
ax.legend( loc = 'upper left')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 2)
ax.plot(df['date'], df['houston_load'], lw=3, label="Actual", c=c5,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['houston_prediction'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dotted',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("Houston")
ax.set_ylim(220000,360000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 3)
ax.plot(df['date'], df['boston_load'], lw=3, label="Actual", c=c5,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['boston_prediction'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dotted',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("Boston")
ax.set_ylim(40000,70000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 4)
ax.plot(df['date'], df['nyc_load'], lw=3, label="Actual", c=c5,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['nyc_prediction'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dotted',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("New York City")
ax.set_ylim(95000,140000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 5)
ax.plot(df['date'], df['chicago_load'], lw=3, label="Actual", c=c5,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['chicago_prediction'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dotted',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_title("Chicago")
ax.set_ylim(160000,260000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 6)
ax.plot(df['date'], df['phila_load'], lw=3, label="Actual", c=c5,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['phila_prediction'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dotted',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_xlabel("Date")
ax.set_title("Philadelphia")
ax.set_ylim(75000,120000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
#plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)

ax = fig.add_subplot(4, 2, 7)
ax.plot(df['date'], df['kck_load'], lw=3, label="Actual", c=c5,alpha=1,linestyle='dashed',marker='o',markersize=2)
ax.plot(df['date'], df['kck_prediction'], lw=3, label="Prediction", c=c2,alpha=1,linestyle='dotted',marker='o',markersize=2)
ax.set_ylabel("Daily Load(kWh)")
ax.set_xlabel("Date")
ax.set_title("Kansas City")
ax.set_ylim(25000,52000)
ax.legend( loc = 'best')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=40))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
#fig.suptitle("Electricity Demand in New York (2009-2020)",fontsize=15)
#fig.autofmt_xdate()

plt.tight_layout()
fig.subplots_adjust(top=0.95)
plt.show()
